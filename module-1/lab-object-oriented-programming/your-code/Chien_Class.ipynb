# %%
class Caniche:
    
    def __init__(self, name, height, n_teeth, age):
        """ On initialise un caniche avec son nom, sa taille et son nombre de dents"""
        self.name = name
        self.height = height
        self.n_teeth = n_teeth
        self.age = age    
        
    def bark(self):
        """ Le chien aboie (fera le même chose pour tous les chiens)  """
        print("OUAF OUAF OUAF")
        return None
    
    def pokemonize(self):
        """ Le chien crie son nom - la méthode ne fera donc pas la même chose pour tous les chiens"""
        print((self.name).upper(), " !!!!! ")
        return None        
        
    def fight(self, inst_of_chien):
        """ The one with more teeth is going to win
            On a besoin de mettre une deuxième instance de la classe caniche
            et on a donc accès au mêmes méthodes sur self et inst_of_chien"""
        if self.n_teeth > inst_of_chien.n_teeth:
            return(self.name)
        elif self.n_teeth < inst_of_chien.n_teeth:
            return(inst_of_chien.name)
        else:
            print("Same number of teeth, look at height????")
            return(None)        
        
    def eat(self, food):
        """ Le chien mange la nourriture food placée en argument """        
        print("{} is eating {}".format(self.name, food))
    
    def transformer(self, inst_dog):
        """Le vieux chien se transforme en loup la nuit?"""
        if inst_dog.age > 5:
            
            print("C'est un loup la nuit, s'il a plus de 5 ans!")
            return(inst_dog.age, "y.o. Yes a real monster!")
        else:
            print(inst_dog.name, ",grow up till 5 y.o")
            return(print(inst_dog.name, inst_dog.age, "y.o"))
    
    def repas(self):
        self.eat("cookie")
    def repasA2(self, other):
        self.eat("pasta")    
        other.eat("pizza")    
hubert.repas()        
rex.repasA2(bob)  
hubert = Caniche('Hubert', 10, 30, 6)
rex = Caniche('Rex', 20, 40, 7)
bob = Caniche('Bob', 30, 40, 2)


print("Rex a plus de dents qu'Hubert?", rex.n_teeth  > hubert.n_teeth)
print("Rex a {rex_n_teeth} et Hubert a {hubert_n_teeth}".format(rex_n_teeth=rex.n_teeth,hubert_n_teeth=hubert.n_teeth))
print("Rex a plus de dents qu'Bob?", rex.n_teeth  > bob.n_teeth)
print("Rex a {rex_n_teeth} et Bob a {bob_n_teeth}".format(rex_n_teeth=rex.n_teeth,
                                                                  bob_n_teeth=bob.n_teeth))
print('\n')

for chien in [rex, hubert, bob]:
    print(chien.name)
    
    chien.bark()
    chien.pokemonize()
    chien.eat("banana")
    chien.transformer(inst_dog=bob)   
    print('\n')

for chien, food in zip([rex, hubert, bob], ["banana", "apple", "bones"]):
    print(chien.name)
    
    chien.bark()
    chien.pokemonize()
    chien.eat("bones")
    
    print('\n')

# On vérifie qu'on a bien le même résultat dans les 2 cas
print("Bob est un loup?", bob.transformer(inst_dog=bob))
print("Hubert est un loup?", hubert.transformer(inst_dog=hubert))
print('\n')
print("{rex_name} fighting against {hubert_name}".format(rex_name=rex.name, hubert_name=hubert.name))
print(hubert.fight(inst_of_chien=rex), "has won the fight, yeah!")
print(rex.fight(inst_of_chien=hubert), "has won the fight")
print('\n')

print("{rex_name} fighting against {bob_name}".format(rex_name=rex.name, bob_name=bob.name))
print(bob.fight(inst_of_chien=rex), "has won the fight!")
print(rex.fight(inst_of_chien=bob), "has won the fight!")
# Out:
# Hubert is eating cookie
# Rex is eating pasta
# Bob is eating pizza
# Rex a plus de dents qu'Hubert? True
# Rex a 40 et Hubert a 30
# Rex a plus de dents qu'Bob? False
# Rex a 40 et Bob a 40
#
#
# Rex
# OUAF OUAF OUAF
# REX  !!!!!
# Rex is eating banana
# Bob ,grow up till 5 y.o
# Bob 2 y.o
#
#
# Hubert
# OUAF OUAF OUAF
# HUBERT  !!!!!
# Hubert is eating banana
# Bob ,grow up till 5 y.o
# Bob 2 y.o
#
#
# Bob
# OUAF OUAF OUAF
# BOB  !!!!!
# Bob is eating banana
# Bob ,grow up till 5 y.o
# Bob 2 y.o
#
#
# Rex
# OUAF OUAF OUAF
# REX  !!!!!
# Rex is eating bones
#
#
# Hubert
# OUAF OUAF OUAF
# HUBERT  !!!!!
# Hubert is eating bones
#
#
# Bob
# OUAF OUAF OUAF
# BOB  !!!!!
# Bob is eating bones
#
#
# Bob ,grow up till 5 y.o
# Bob 2 y.o
# Bob est un loup? None
# C'est un loup la nuit, s'il a plus de 5 ans!
# Hubert est un loup? (6, 'y.o. Yes a real monster!')
#
#
# Rex fighting against Hubert
# Rex has won the fight, yeah!
# Rex has won the fight
#
#
# Rex fighting against Bob
# ...
