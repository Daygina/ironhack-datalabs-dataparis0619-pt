# %%
import tweepy
import json
import pandas as pd
API_KEY = "QYIwGBMHF6DSVIg6nHOvjp4Cr"
API_SECRET = "QphkPkdcVXAUqobfme8dboBd6ZfOnxhfFlGQeVRdvg5CAyKMcB"
ACCESS_TOKEN = "2485044523-Ky0wnVN29MDv6jb1B7ROsRP1ZLVsR8vTXgFxE3D"
ACCESS_TOKEN_SECRET = "d7xN5hBWyqpsCLX2DcTmNbl5kwVpuK1x3yZmG6dlc38m7"

auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# 1885741477
# Mcomme musicienne : le destind'Alma Rosé. #geniefeminin il y a quelques années radio classique m avait donné un esp… https://t.co/RtQGgqaxqs
# M comme musicienne : le destin d' Alma Rosé... https://t.co/HARzuT7ql0 via @lemondefr
# RT @nathlequeux: Souvenez-vous de cette terrible tentative de suicide d’un #MNA au TGI de paris en novembre dernier...
# Le jeune a enfin été…
# RT @mhall119: Ironically, the people telling Americans that if they don't like their government they should leave, are the same people tell…
# RT @ubuntu: microK8s gives you a single-node #Kubernetes deployment for workstations and appliances. @jlwallen of @TechRepublic explains mo…
# [MAJ] Le HTC Wildfire apparaît sur un site russe : https://t.co/3xb9gUYbOp
# [MAJ] Samsung Galaxy Tab S6 : un nouveau rendu presse : https://t.co/8Xt4coYhtg
# [MAJ] Honor 9x : de nouveaux rendus presse : https://t.co/xsr1rKK65O
# ...

# %%
public_tweets = api.statuses_lookup()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-51236b01faa4> in <module>
# ----> 1 public_tweets = api.statuses_lookup()
#
# TypeError: statuses_lookup() missing 1 required positional argument: 'id_'

# %%
public_tweets = api.user_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# 1885741477
# RT @IWriteMonsters: My daughter insisted on this costume. All the other parents at daycare will think I've never read a comic book. #Hallow…
# RT @TopForPhone: Qualcomm Snapdragon 636 : taillé pour le borderless : https://t.co/KVSn4Urf1Z [MAJ]
# RT @bouyguestelecom: Agissons pour la 🌍 et recyclons nos vieux mobiles avec Bouygues Telecom. 1 mobile ♻️ = 1€ reversé au @WWFFrance https:…
# RT @SpicyB9: @ALCATEL1TOUCHUK I've has my #Idol3 for a month now and I'm mega impressed you'll have LG, Sony and HTC thinking twice. Well d…
# RT @PlayTouchRL: This week we’ve had Ice Lollies at @BatleyRLFC, new @ALCATEL1TOUCHUK balls at @OSJTouchRugby and rain at @activehull http:…
# RT @droidcon: Droidcon NYC 2014 http://t.co/hZPvhXrFNm
# RT @ALCATEL1TOUCHUK: Our @leedsrhinos fan, Mrs Sian Lavery winning £1K worth of mobile technology at the @SuperLeague #challengecupfinal ht…
# ...

# %%
public_tweets = api.retweets_of_me()
for tweet in public_tweets:
    print(tweet.text)   
# Returns the 20 most recent tweets of the authenticated user that have been retweeted by others. Output: empty, which is normal

# %%
public_tweets = api.mentions_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# @DayginaE I'm not a fisherman, I'm a Templar! ;-) http://t.co/n0Lwj4Hp9V

# %%
def get_followers(user, count=100):
    results = api.followers(user, count=count)
    followers = [pd.Series(follower._json) for follower in results]
    df = pd.DataFrame(followers)
    return df

myfollowers = get_followers('DayginaE')
myfollowers
# Out:
#             id      id_str              name     screen_name  \
# 0    397158932   397158932             Sonia        sonka149
# 1    174318170   174318170        Jiong Ding    poorest_1212
# 2    133475617   133475617           Gonzalo   gonzalocoello
# 3   3065989245  3065989245         Mix It Up     MixitupTeam
# 4     15524452    15524452        paula rita    parismechama
# 5    113493726   113493726      Michael Chen      michaeltct
# 6     79465875    79465875    Frédéric Surin   FredericSurin
# 7     17373384    17373384  Julien Guézennec          guezeg
# 8   1885741477  1885741477   Florence Sardas       FloSardas
# 9     48305195    48305195               frd           dafrd
# 10  2518585876  2518585876  Frederic Alcatel   dafrd_alcatel
# 11   404852513   404852513    Ketil Høigaard        sentisis
# 12     7508032     7508032  Christophe Wiest     christopheW
# 13  1092191288  1092191288  beatrice thiriet  BeatricThiriet
# ...

# %%
from pandas.io.json import json_normalize
getstatus = api.get_status(1885741477)
results = getstatus.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-f07f0624cf0e> in <module>
#       1 from pandas.io.json import json_normalize
#       2 getstatus = api.get_status(1885741477)
# ----> 3 results = getstatus.json()
#
# AttributeError: 'Status' object has no attribute 'json'

# %%
#updatemedia = api.update_with_media(2485044523)
# Update the authenticated user’s status. Statuses that are duplicates or too long will be silently ignored.

# %%
getuser = api.get_user(1885741477)
getuser
#'name': 'Florence Sardas', 'screen_name': 'FloSardas',
# Out:
# User(_api=<tweepy.api.API object at 0x0000029061416668>, _json={'id': 1885741477, 'id_str': '1885741477', 'name': 'Florence Sardas', 'screen_name': 'FloSardas', 'location': 'Paris, France', 'profile_location': None, 'description': 'Partner @Mazars, Consultant and Auditor in IS and risk management @MazarsGroup, ex-marketing @Microsoft, interested in #tech, #digital, innovation, IA, ...', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 308, 'friends_count': 491, 'listed_count': 46, 'created_at': 'Fri Sep 20 07:31:54 +0000 2013', 'favourites_count': 315, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1206, 'lang': None, 'status': {'created_at': 'Thu Jun 27 09:01:06 +0000 2019', 'id': 1144168767460691968, 'id_str': '1144168767460691968', 'text': 'RT @virgini80610211: Amazing panel on innovation in financial services at Mazars FS seminar @SGCameroun @DauphineTunis @Neilabenzina @Clair…', 'tru
# ...

# %%
about_me= api.me()
about_me
#mon id: 2485044523
# Out:
# User(_api=<tweepy.api.API object at 0x0000029061416668>, _json={'id': 2485044523, 'id_str': '2485044523', 'name': 'Daygina', 'screen_name': 'DayginaE', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 15, 'friends_count': 25, 'listed_count': 0, 'created_at': 'Fri May 09 08:34:29 +0000 2014', 'favourites_count': 8, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 32, 'lang': None, 'status': {'created_at': 'Fri Jul 19 07:19:33 +0000 2019', 'id': 1152115743179325440, 'id_str': '1152115743179325440', 'text': '1885741477', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://twitter.com/DayginaE" rel="nofollow">Daygina </a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to
# ...

# %%
API.show_friendship(source_id/source_screen_name, target_id/target_screen_name)

# %%
m=api.friends_ids(1885741477)
m
# Out:
# [974603180427358208,
#  600304356,
#  29701712,
#  1512746144,
#  735104439594409985,
#  2503252377,
#  110656748,
#  2205307848,
#  14237828,
#  943123341824675841,
#  80528373,
#  920981440355061760,
#  586459456,
#  890247999896645632,
#  435195010,
#  42749944,
#  2579780782,
#  14282999,
#  892702990578135040,
#  844544276306542597,
#  966709335404482568,
#  1704231050,
#  1037451650,
#  2209010881,
#  3164012037,
#  9737032,
#  260833756,
#  957896923050139648,
#  602733907,
#  254263052,
#  137303937,
#  196071988,
#  95868974,
#  122029488,
#  256902973,
#  95868501,
#  939116302916112392,
#  569345790,
#  321306576,
#  2885288452,
#  595479894,
#  299772148,
#  841437061,
#  202590356,
#  973971846,
#  1150505682,
#  1343319908,
#  477356399,
#  89468672,
#  14623301,
#  2196074485,
#  17655326,
#  2989469177,
#  128544477,
#  879247659898474496,
#  313291590,
#  2284237477,
#  227463701,
#  1706742654,
#  3551532493,
#  3650793623,
#  48815318,
#  2462072253,
# ...

# %%
m=api.followers_ids(1885741477)
m
# Out:
# [2885288452,
#  1129389152892522497,
#  120818228,
#  832184295821340672,
#  1129492875471986688,
#  1037451650,
#  385050578,
#  951753981390356481,
#  844561990341283840,
#  2197828004,
#  100759064,
#  2791920306,
#  331518643,
#  2954457267,
#  321306576,
#  1079292948146200576,
#  2503252377,
#  586459456,
#  913304238,
#  557996780,
#  123056407,
#  40552426,
#  42749944,
#  183296327,
#  179481835,
#  4622699369,
#  39060800,
#  1917075186,
#  1049614301521203201,
#  508656618,
#  435195010,
#  390511552,
#  17655326,
#  1015176547068710912,
#  569422435,
#  981187644859273228,
#  2296081640,
#  939116302916112392,
#  3164012037,
#  2579780782,
#  935905544988184576,
#  164348324,
#  739789244479201284,
#  725617818935369728,
#  478416871,
#  974603180427358208,
#  3611254997,
#  731720274,
#  966709335404482568,
#  957896923050139648,
#  957381088749543425,
#  2939148038,
#  777817623383769088,
#  23179422,
#  756837984998035456,
#  864285827056238593,
#  862695574851780609,
# ...

# %%
query_search=api.search(q/)
query_search
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-83c88e1880f4> in <module>
# ----> 1 query_search=api.search(q)
#       2 query_search
#
# NameError: name 'q' is not defined
