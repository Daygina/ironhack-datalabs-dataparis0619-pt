# %%
import tweepy
import pandas as pd
API_KEY = "QYIwGBMHF6DSVIg6nHOvjp4Cr"
API_SECRET = "QphkPkdcVXAUqobfme8dboBd6ZfOnxhfFlGQeVRdvg5CAyKMcB"
ACCESS_TOKEN = "2485044523-Ky0wnVN29MDv6jb1B7ROsRP1ZLVsR8vTXgFxE3D"
ACCESS_TOKEN_SECRET = "d7xN5hBWyqpsCLX2DcTmNbl5kwVpuK1x3yZmG6dlc38m7"

auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
def get_followers(user, count=100):
    results = api.followers(user, count=count)
    followers = [pd.Series(follower._json) for follower in results]
    df = pd.DataFrame(followers)
    return df

ironhack = get_followers('ironhack')
ironhack.head(10)
# Out:
#                     id               id_str              name  \
# 0           3395524173           3395524173      AlexsCarmona
# 1           1207206091           1207206091  موقع رجل الأعمال
# 2   763884407623155712   763884407623155712            cyphra
# 3             19785694             19785694   Cornelius Hardy
# 4  1151097156348108800  1151097156348108800   Chanty Herrmann
# 5   859449822855802886   859449822855802886      Startupistan
# 6             96030961             96030961         Dobermann
# 7   823316342052966402   823316342052966402        StudioData
# 8            171629733            171629733      Daniel Duque
# 9           2229402134           2229402134              DATE
#
#        screen_name                  location  \
# 0     AlexsCarmona  Distrito Federal, México
# 1  BusinessmanSite         السعودية - الرياض
# 2       tecknolabs
# 3   CorneliusHardy                Orlando Fl
# 4   ChantyHerrmann
# 5    Startupistan1               Afghanistan
# 6    JohnDobermann
# 7  StudioDataChile       Viña del Mar, Chile
# 8     DanielFDuque       Panama City, Panama
# 9  shiroiusagi4486
#
#                                          description                      url  \
# 0  Live a life you will remember👣 / Venezolano🇻🇪 ...  https://t.co/XSU94F7HHW
# 1  موقع رجـل الأعمـال السعـودي موقع يتخصص في الدع...   http://t.co/OvBS0UEYrc
# 2                                                                        None
# 3  Founder at Cornelius Hardy. https://t.co/t2o1N...  https://t.co/S5PEmgPQzL
# 4  anthropologist working in tech and learning to...                     None
# 5  We are a digital academy & entrepreneurial pla...  https://t.co/Ct9b4966hB
# 6  📈Trading 🔴Streams 🤯Marketing 🔪Ex-chef | Antes ...                     None
# 7  Somos una empresa altamente especializada en e...  https://t.co/1GRRbuhvP4
# 8              Emprendedor, fundador de @clubprepago                     None
# 9  Lector versatil, videojugador ahora casual, en...                     None
#
#                                             entities  protected  \
# 0  {'url': {'urls': [{'url': 'https://t.co/XSU94F...      False
# 1  {'url': {'urls': [{'url': 'http://t.co/OvBS0UE...      False
# 2                      {'description': {'urls': []}}      False
# 3  {'url': {'urls': [{'url': 'https://t.co/S5PEmg...      False
# 4                      {'description': {'urls': []}}      False
# 5  {'url': {'urls': [{'url': 'https://t.co/Ct9b49...      False
# 6                      {'description': {'urls': []}}      False
# 7  {'url': {'urls': [{'url': 'https://t.co/1GRRbu...      False
# 8                      {'description': {'urls': []}}      False
# 9                      {'description': {'urls': []}}      False
#
#    followers_count  ...  default_profile  default_profile_image following  \
# 0               43  ...             True                  False     False
# 1             1037  ...            False                  False     False
# 2               28  ...            False                  False     False
# 3              392  ...            False                  False     False
# 4                2  ...             True                  False     False
# 5               19  ...             True                  False     False
# 6              715  ...            False                  False     False
# 7               30  ...            False                  False     False
# 8              100  ...            False                  False     False
# 9               25  ...            False                  False     False
#
#    live_following follow_request_sent notifications  muting  blocking  \
# 0           False               False         False   False     False
# 1           False               False         False   False     False
# 2           False               False         False   False     False
# 3           False               False         False   False     False
# 4           False               False         False   False     False
# 5           False               False         False   False     False
# 6           False               False         False   False     False
# 7           False               False         False   False     False
# 8           False               False         False   False     False
# 9           False               False         False   False     False
#
#    blocked_by translator_type
# 0       False            none
# 1       False            none
# 2       False            none
# 3       False            none
# 4       False            none
# 5       False            none
# 6       False            none
# 7       False            none
# 8       False            none
# 9       False            none
#
# [10 rows x 47 columns]
