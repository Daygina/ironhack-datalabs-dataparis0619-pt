# %%
import json
import requests
import os
import pandas as pd

#my_api_token = os.environ.get('api_key', None)

# %%
#Challenge 1: how many programming languages are used among all the forks created from the main lab repo of your bootcamp.
cfg_path = open("cfg_path").read()

# %%
url='https://api.github.com/repos/mayadesp/ironhack-datalabs-dataparis0619-pt/forks'
# need to add argument , headers={"authentication": "token <token>"}
response = requests.get(url, headers={"authentication": "api_key"})
results = response.json()

# %%
print(api_key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-0d2e46aca3aa> in <module>
# ----> 1 print(api_key)
#
# NameError: name 'api_key' is not defined

# %%
data = pd.DataFrame(results)
data.head(3)
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/flotalavera/ironh...     False
# 1  https://api.github.com/repos/orianegsx/ironhac...     False
# 2  https://api.github.com/repos/Amibam/ironhack-d...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/flotalavera/ironh...
# 1  https://api.github.com/repos/orianegsx/ironhac...
# 2  https://api.github.com/repos/Amibam/ironhack-d...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/flotalavera/ironh...
# 1  https://api.github.com/repos/orianegsx/ironhac...
# 2  https://api.github.com/repos/Amibam/ironhack-d...
#
#                                         branches_url  \
# 0  https://api.github.com/repos/flotalavera/ironh...
# 1  https://api.github.com/repos/orianegsx/ironhac...
# 2  https://api.github.com/repos/Amibam/ironhack-d...
#
#                                            clone_url  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 73 columns):
# archive_url          13 non-null object
# archived             13 non-null bool
# assignees_url        13 non-null object
# blobs_url            13 non-null object
# branches_url         13 non-null object
# clone_url            13 non-null object
# collaborators_url    13 non-null object
# comments_url         13 non-null object
# commits_url          13 non-null object
# compare_url          13 non-null object
# contents_url         13 non-null object
# contributors_url     13 non-null object
# created_at           13 non-null object
# default_branch       13 non-null object
# deployments_url      13 non-null object
# description          0 non-null object
# disabled             13 non-null bool
# downloads_url        13 non-null object
# events_url           13 non-null object
# fork                 13 non-null bool
# forks                13 non-null int64
# ...

# %%
data["language"].unique()
#data.language - HTML and Jupiter
# Out:
# array(['Jupyter Notebook', 'HTML'], dtype=object)

# %%
#data.full_name

# %%
#data["commits_url"].unique()

# %%
#data["commits_url"].count()

# %%
#from pandas.io.json import json_normalize

#results = response.json()
#flattened_data = json_normalize(results)

#flattened_data.head(3)
