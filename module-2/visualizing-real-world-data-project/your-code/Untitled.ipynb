# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Read from CSV with correction of the Index column to DateTime Index
#     1) Initially dataframe has Date col as format 19/08/2004 and object( befor passing the arg "parse_dates").
#
#     2) parse_dates=["Date"]   ==> transformes the Col Date to  type "datetime64[ns]"  in 2004-08-19 format!
#
#     3) index_col="Date" => Index of the DF is col Date instead of Col Index (0,1,2,3...)

# %%
df=pd.read_csv('../GAFA Stock Prices.csv', parse_dates=["Date"], index_col="Date")
df.head()
#df1['period']
# Out:
#              Stock       Open       High        Low      Close  Adj Close  \
# Date
# 2004-08-19  Google  49.676899  51.693783  47.669952  49.845802  49.845802
# 2004-08-20  Google  50.178635  54.187561  49.925285  53.805050  53.805050
# 2004-08-23  Google  55.017166  56.373344  54.172661  54.346527  54.346527
# 2004-08-24  Google  55.260582  55.439419  51.450363  52.096165  52.096165
# 2004-08-25  Google  52.140873  53.651051  51.604362  52.657513  52.657513
#
#                 Volume
# Date
# 2004-08-19  44994500.0
# 2004-08-20  23005800.0
# 2004-08-23  18393200.0
# 2004-08-24  15361800.0
# 2004-08-25   9257400.0

# %%
print(df.dtypes)
# Out:
# Stock         object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
df.groupby(['Date','Stock'])['Adj Close'].mean().unstack().plot(figsize=(20,10))
plt.title('Adjusted Close. Total by Day/ Year and Stock')
plt.show()

# %%
df1=df["Adj Close"].resample('Q').mean()
print(df1)
# Out:
# Date
# 1980-12-31      0.024732
# 1981-03-31      0.021366
# 1981-06-30      0.022373
# 1981-09-30      0.017986
# 1981-12-31      0.017394
#                  ...
# 2017-12-31    590.098195
# 2018-03-31    724.756457
# 2018-06-30    711.307989
# 2018-09-30    709.244618
# 2018-12-31    705.115981
# Freq: Q-DEC, Name: Adj Close, Length: 153, dtype: float64
