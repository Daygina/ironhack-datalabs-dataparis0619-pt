# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include =['float64', 'int64']).head(2)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833

# %%
#your code here- categorical variable
titanic.select_dtypes(exclude=['float64', 'int64']).head(2)
# Out:
#                                                 Name  Gender     Ticket Cabin  \
# 0                            Braund, Mr. Owen Harris    male  A/5 21171    U0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   PC 17599   C85
#
#   Embarked
# 0        S
# 1        C

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
#plt.figure(figsize=(12,6))
# import matplotlib as mpl
# mpl.rcParams['lines.linewidth'] = 2
# mpl.rcParams['lines.color'] = 'r'
plt.style.use('classic')
plt.rcParams['figure.figsize']=(12,6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
titanic['Age'].plot.hist()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
plt.plot([1,4,4])
plt.subplot(121)
titanic['Age'].plot.hist(bins=10)

plt.subplot(222)
titanic['Age'].plot.hist(bins=20)

plt.subplot(224)
titanic['Age'].plot.hist(bins=50)
plt.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
#sns.set(style='darkgrid')
sns.set_style("whitegrid")
#sns.set_style("ticks", {"xtick.major.size": 12, "ytick.major.size": 6})

# %%
#sns.violinplot("Age", data=titanic, widths=50, showmeans=True, showextrema=True, showmedians=True, points=500)
#Axes.violinplot(self, dataset, positions=None, vert=True, widths=0.5, showmeans=False, showextrema=True, showmedians=False, points=100, bw_method=None, *, data=Non

# %%
ax=sns.distplot(titanic['Age'])

# %%
ax=sns.distplot(titanic['Age'], bins=50)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
titanic['Gender'].value_counts().plot(kind='bar')

# %%
sns.countplot(x='Gender', hue='Gender', data=titanic, palette="Greens_d")

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
titanic['Pclass'].plot.hist(figsize=(3,3))

# %%
titanic['Pclass'].value_counts().plot.bar(figsize=(3,3))

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
titanic['Age'].describe().plot.barh()

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
sns.violinplot(titanic['Age'])

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.jointplot(x='Age', y='Fare', data=titanic)

# %%
# your code-2nd way
titanic(['Age','Fare'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-810c2e135c0d> in <module>
#       1 # your code-2nd way
# ----> 2 titanic(['Age','Fare'])
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
sns.heatmap(titanic.corr(), center=1, annot=True, fmt="f", linewidths=2)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
titanic[['Pclass', 'Age']]
# Out:
#       Pclass        Age
# 0          3  22.000000
# 1          1  38.000000
# 2          3  26.000000
# 3          1  35.000000
# 4          3  35.000000
# 5          3  23.926502
# 6          1  54.000000
# 7          3   2.000000
# 8          3  27.000000
# 9          2  14.000000
# 10         3   4.000000
# 11         1  58.000000
# 12         3  20.000000
# 13         3  39.000000
# 14         3  14.000000
# 15         2  55.000000
# 16         3   2.000000
# 17         2  32.172868
# 18         3  31.000000
# 19         3  27.749836
# 20         2  35.000000
# 21         2  34.000000
# 22         3  15.000000
# 23         1  28.000000
# 24         3   8.000000
# 25         3  38.000000
# 26         3  27.749836
# 27         1  19.000000
# 28         3  22.581283
# 29         3  27.824180
# ...      ...        ...
# 1279       3  21.000000
# 1280       3   6.000000
# 1281       1  23.000000
# 1282       1  51.000000
# 1283       3  13.000000
# 1284       2  47.000000
# ...

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#sns.relplot(x='Age', y='Gender', hue="Age", size='Gender', data=titanic)

# %%
g=sns.FacetGrid(data=titanic, col='Gender')
g.map(plt.hist, "Age")

# %%
sns.FacetGrid(data=titanic, col='Gender').map(plt.hist, "Age")
