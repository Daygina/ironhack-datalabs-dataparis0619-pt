# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp=pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
temp.dtypes
#City and State are categorical - panda denotes them as object
#Temperature a number
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer 
temp.loc[temp.State == 'New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp.loc[temp.State == 'New York'].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp.loc[temp.Temperature>=15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp['City'].loc[temp.Temperature >=15]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp['City'][(temp.Temperature >=15 ) & (temp.Temperature<20)]
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
gb=temp.groupby('State')

# %%
dfx=gb['Temperature'].agg([np.mean, np.std])

# %%
dfx
# Out:
#                   mean       std
# State
# Connecticut  15.833333  1.964186
# New Jersey   21.111111  1.571348
# New York     10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee=pd.read_csv('employee.csv')

# %%
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
import matplotlib
# %matplotlib inline
employee.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000014F3422BCF8>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
employee.Salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
employee.Salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employee.loc[employee.Salary == employee.Salary.min()]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
employee.iloc[2]
# Out:
# Name            David
# Department         HR
# Education      Master
# Gender              M
# Title         analyst
# Years               2
# Salary             30
# Name: 2, dtype: object

# %% [markdown]
# #### Could you give only David's salary?

# %%
employee.loc[2, 'Salary']
# Out:
# 30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
employee.loc[employee.Title == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee.Name[(employee.Title == 'associate') & (employee.Salary>55)]
# Out:
# 7    Pedro
# Name: Name, dtype: object

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
employee.sort_values(by='Years')
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 4  Samuel      Sales    Master      M  associate      3      55
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 7   Pedro         IT       Phd      M  associate      7      60
# 6  Carlos         IT    Master      M         VP      8      70
# 8     Ana         HR    Master      F         VP      8      70

# %%
employee.groupby('Years')['Salary'].mean()
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %%
employee.groupby('Title')['Salary'].mean()
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %% [markdown]
# ####  What is the average Salary per title?

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
employee.plot.box(vert=True)

# %%
employee.boxplot()

# %%
employee.plot.box(vert=False)

# %%
# print first quartile here
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
employee.groupby('Gender')['Salary'].mean()
#yes different.
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
employee.groupby('Department')['Salary'].agg([np.mean, np.min, np.max])
# Out:
#              mean  amin  amax
# Department
# HR          45.00    30    70
# IT          48.75    30    70
# Sales       55.00    55    55

# %%
employee.groupby('Department')['Years'].agg([np.mean, np.min, np.max])
# Out:
#                 mean  amin  amax
# Department
# HR          4.666667     2     8
# IT          4.500000     1     8
# Sales       2.500000     2     3

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
gb_dept=employee.groupby('Department')
df_diff=gb_dept['Salary'].agg([np.max, np.min])
df_diff
# Out:
#             amax  amin
# Department
# HR            70    30
# IT            70    30
# Sales         55    55

# %%
df_diff['Difference']=df_diff['amax']-df_diff['amin']

# %%
df_diff
# Out:
#             amax  amin  Difference
# Department
# HR            70    30          40
# IT            70    30          40
# Sales         55    55           0

# %% [markdown]
# # Challenge 3

# %%
orders = pd.read_csv('Orders.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
orders.head(3)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
#
#                           Description  Quantity          InvoiceDate  \
# 0  white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                 white metal lantern         6  2010-12-01 08:26:00
# 2      cream cupid hearts coat hanger         8  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
# your answer here
#there are 397924 lines in the CSV, this is why the count function shows the same number in all cols
#cols Unnamed and InvoiceNo, CustomerID have no sense.
#the dataset represent namely the cells over year 2011 with less sells in 2010
# there are some outliers in the Quantity and UnitPrice columns. As std dev is 22,1 for the mean of 3,1 and the 75% percentile in the range of 3,75.
#The max price of 8142,8 is an outlier
#also the price of 0,00 need to be understand - was a promo action, or a replacement or the product?
#one produt was sold 80995 qty, while the mean sell out quantity is 13,02 and the 75% percentile to be 12,0.

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders.UnitPrice.mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
orders.UnitPrice.min()
# Out:
# 0.0

# %%
orders.UnitPrice.max()
# Out:
# 8142.75

# %%
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# 5                5     536365     22752  2010     12    3     8
# 6                6     536365     21730  2010     12    3     8
# 7                7     536366     22633  2010     12    3     8
# 8                8     536366     22632  2010     12    3     8
# 9                9     536367     84879  2010     12    3     8
# 10              10     536367     22745  2010     12    3     8
# 11              11     536367     22748  2010     12    3     8
# 12              12     536367     22749  2010     12    3     8
# 13              13     536367     22310  2010     12    3     8
# ...

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
sp_customers=orders[orders['CustomerID'].notnull() & (orders['Country'] == "Spain")]

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
sp_customers.head(3)
# Out:
#       Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250        6421     536944     22383  2010     12    5    12
# 4251        6422     536944     22384  2010     12    5    12
# 4252        6423     536944     20727  2010     12    5    12
#
#                   Description  Quantity          InvoiceDate  UnitPrice  \
# 4250  lunch bag suki  design         70  2010-12-03 12:20:00       1.65
# 4251  lunch bag pink polkadot       100  2010-12-03 12:20:00       1.45
# 4252  lunch bag  black skull.        60  2010-12-03 12:20:00       1.65
#
#       CustomerID Country  amount_spent
# 4250       12557   Spain         115.5
# 4251       12557   Spain         145.0
# 4252       12557   Spain          99.0

# %%
sp_customers.shape
#there are 2485 customerID from Spain.
# Out:
# (2485, 14)

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
orders['CustomerID'].loc[orders.Quantity >50]
# Out:
# 46        13748
# 83        15291
# 96        14688
# 102       14688
# 174       16029
# 175       16029
# 176       16029
# 177       16029
# 178       16029
# 179       16029
# 180       16029
# 215       17511
# 217       17511
# 218       17511
# 219       17511
# 222       17511
# 223       17511
# 225       17511
# 231       17511
# 232       17511
# 245       13408
# 246       13408
# 247       13408
# 248       13408
# 376       12791
# 406       14045
# 673       13255
# 718       13694
# 719       13694
# 720       13694
#           ...
# 397113    18102
# 397114    18102
# 397115    18102
# 397116    18102
# 397117    18102
# 397118    18102
# 397119    17949
# 397120    17949
# 397155    13077
# 397330    12433
# 397336    12433
# 397344    12433
# 397351    12433
# 397371    12433
# 397372    12433
# 397380    12433
# 397448    17490
# 397451    16446
# 397454    17389
# 397471    15694
# 397563    12985
# 397572    12985
# 397586    12985
# 397622    17754
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders[(orders['Quantity']>50) & (orders['Country'] == "Spain")].head(5)
# Out:
#       Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250        6421     536944     22383  2010     12    5    12
# 4251        6422     536944     22384  2010     12    5    12
# 4252        6423     536944     20727  2010     12    5    12
# 4253        6424     536944     20725  2010     12    5    12
# 4254        6425     536944     20728  2010     12    5    12
#
#                   Description  Quantity          InvoiceDate  UnitPrice  \
# 4250  lunch bag suki  design         70  2010-12-03 12:20:00       1.65
# 4251  lunch bag pink polkadot       100  2010-12-03 12:20:00       1.45
# 4252  lunch bag  black skull.        60  2010-12-03 12:20:00       1.65
# 4253  lunch bag red retrospot        70  2010-12-03 12:20:00       1.65
# 4254      lunch bag cars blue       100  2010-12-03 12:20:00       1.45
#
#       CustomerID Country  amount_spent
# 4250       12557   Spain         115.5
# 4251       12557   Spain         145.0
# ...

# %% [markdown]
# #### Select all free orders

# %%
free=orders[orders.UnitPrice ==0]

# %%
free
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %%
free.shape
#40 rows with free orders - UnitPrice 0.00
# Out:
# (40, 14)

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
orders[orders.Description.str.contains('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# 361            370     536401     20726  2010     12    3    11
# 362            371     536401     22384  2010     12    3    11
# 402            411     536404     22383  2010     12    3    11
# 403            412     536404     20728  2010     12    3    11
# 404            413     536404     20727  2010     12    3    11
# 532            541     536412     20728  2010     12    3    11
# 533            542     536412     22382  2010     12    3    11
# 535            544     536412     22662  2010     12    3    11
# 536            545     536412     22383  2010     12    3    11
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
y=orders[(orders.Description.str.contains('lunch bag')) & (orders.year == 2011)]

# %%
y
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# 26861        43617     540098     22383  2011      1    2    15
# 26862        43618     540098     22382  2011      1    2    15
# 26863        43619     540098     20727  2011      1    2    15
# 26864        43620     540098     20727  2011      1    2    15
# 26902        43658     540099     20725  2011      1    2    16
# 26903        43659     540099     20726  2011      1    2    16
# 27118        44179     540157     22384  2011      1    3    11
# 27242        44329     540168     22383  2011      1    3    12
# 27360        44448     540176     22382  2011      1    3    12
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
amount=orders[(orders.Country == 'Spain')]['amount_spent']

# %%
amount.value_counts()
# Out:
# 15.00     186
# 17.70     122
# 19.80      99
# 17.40      86
# 10.20      76
# 30.00      59
# 14.85      56
# 16.50      56
# 12.60      50
# 10.50      43
# 13.20      41
# 5.04       39
# 9.90       38
# 17.00      35
# 15.30      34
# 15.90      33
# 23.40      31
# 19.90      28
# 12.50      24
# 12.75      24
# 20.40      24
# 25.50      23
# 10.08      21
# 16.95      20
# 8.50       20
# 7.50       20
# 5.90       19
# 3.75       19
# 7.80       18
# 19.50      17
#          ...
# 2.52        1
# 14.94       1
# 66.24       1
# 78.00       1
# 3.36        1
# 290.00      1
# 11.85       1
# 7.47        1
# 97.80       1
# 21.90       1
# 91.80       1
# 23.90       1
# 8.67        1
# 23.70       1
# 9.30        1
# 2.60        1
# 46.75       1
# 4.98        1
# 44.55       1
# 3.36        1
# 6.76        1
# 29.88       1
# 0.42        1
# 3.35        1
# 11.52       1
# 29.85       1
# 7.56        1
# 280.00      1
# 360.00      1
# 4.74        1
# ...

# %%
amount.hist(bins=50)

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders.loc[orders.month == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# 199480      285426     561905     84978  2011      8    1     9
# 199481      285427     561905     21754  2011      8    1     9
# 199482      285428     561905     23226  2011      8    1     9
# 199483      285429     561905     21715  2011      8    1     9
# 199484      285430     561905     21716  2011      8    1     9
# 199485      285431     561905     21746  2011      8    1     9
# 199486      285432     561905     21755  2011      8    1     9
# 199487      285433     561906     22367  2011      8    1    10
# 199488      285434     561906     20914  2011      8    1    10
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
orders.month.value_counts()
# Out:
# 11    64545
# 10    49557
# 12    43464
# 9     40030
# 5     28322
# 6     27185
# 3     27177
# 8     27013
# 7     26827
# 4     22644
# 1     21232
# 2     19928
# Name: month, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
orders.columns
# Out:
# Index(['Unnamed: 0', 'InvoiceNo', 'StockCode', 'year', 'month', 'day', 'hour',
#        'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID',
#        'Country', 'amount_spent'],
#       dtype='object')

# %%
orders.groupby('Country')['amount_spent'].mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
orders.loc[orders.UnitPrice==orders.UnitPrice.max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
orders.groupby('year')['amount_spent'].mean()
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
