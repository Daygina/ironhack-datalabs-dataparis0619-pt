# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://play.google.com/store/apps/details?id=com.tnscreen.main&hl=fr&showAllReviews=true'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
list_names = soup.find_all('div jscontroller')
list_names
# Out:
# []
